# %% [markdown]
# ## ML Training

# %%
import pandas as pd 
data = pd.read_csv('C:/Users/mlalw/OneDrive/Desktop/data_259/Book1 - Sheet1.csv')

# %%
data
# Out:
#                                                   text Classification
# 0    Looking at data collections VII–X, more than 6...    Social Need
# 1    Social sexing remains illegal in most countrie...    Social Need
# 2    Most, if not all, chromosome screening panels ...    Social Need
# 3     It is important to monitor the use and safety...   Medical Need
# 4    Preimplantation diagnosis of inherited disease...   Medical Need
# ..                                                 ...            ...
# 394  Several research trials have already been run ...   Medical Need
# 395  The comparative affordability, efficiency, sca...   Medical Need
# 396  When we started our lab, one of the big things...   Medical Need
# 397   These can expand our cell engineering capabil...   Medical Need
# 398  A CRISPR/Cas9 complex targeting the mutated Hu...   Medical Need
#
# [399 rows x 2 columns]
